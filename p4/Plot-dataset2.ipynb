# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot_training_loss(history, epochs):
    plt.style.use("ggplot")
    plt.plot(np.arange(0, epochs), history['loss'])
    plt.plot(np.arange(0, epochs), history['val_loss'])
    plt.title('Training Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train_loss', 'val_loss'], loc='upper left')
    plt.show()
    
def plot_accuracy_loss(history, epochs):
    plt.style.use("ggplot")
    plt.plot(np.arange(0, epochs), history['acc'])
    plt.plot(np.arange(0, epochs), history['val_acc'])
    plt.title('Training Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train_acc', 'val_acc'], loc='upper left')
    plt.show()

# %% [markdown]
# # 1st Training
# **Baseline Model:** ResNet50
# <br>
# **Optimizer:** SGD, with learning rate 0.0001
# <br>
# **Image shape:** 299x299x3
# <br>
# **Validation Accuracy:** 0.0106
# <br>
# **Training Accuracy:** 0.5154

# %%
with open('dataset2/resnet_sgd.pkl', 'rb') as f:
    history = pickle.load(f)
history
# Out:
# {'acc': [0.04518072290233819,
#   0.14325301204101148,
#   0.2533734939471785,
#   0.3203614457544074,
#   0.36975903614457833,
#   0.4154216867828944,
#   0.4502409639272345,
#   0.47385542165802186,
#   0.49433734928268985,
#   0.5154216868331634],
#  'loss': [4.739461394160627,
#   3.619562821330794,
#   3.0423779348580235,
#   2.6359702187273877,
#   2.399504864014775,
#   2.191915062019624,
#   2.043706721685019,
#   1.9243414472097373,
#   1.848085272053638,
#   1.743735242866608],
#  'val_acc': [0.014114911989372302,
#   0.014447027565592825,
#   0.015111258718033876,
#   0.012620391901328848,
#   0.00846894719362338,
#   0.009133178346064431,
#   0.007970773829292593,
#   0.00846894719362338,
#   0.010129525074726005,
#   0.010627698439056792],
#  'val_loss': [4.6556540167399,
#   4.712710387047166,
#   4.735962184708367,
#   4.804505645615126,
#   4.872979678176479,
#   4.887676239805497,
#   4.955234922233589,
#   4.9513111078078,
#   5.000981250263773,
# ...

# %%
EPOCHS = 10

# %%
plot_training_loss(history, EPOCHS)

# %%
plot_accuracy_loss(history, EPOCHS)

# %% [markdown]
# # 2nd Training
# **Baseline Model:** InceptionResNetV2
# <br>
# **Optimizer:** SGD, with learning rate 0.0001
# <br>
# **Image shape:** 299x299x3
# <br>
# **Validation Accuracy:** 0.9350
# <br>
# **Training Accuracy:** 0.8228

# %%
with open('dataset2/inception_sgd.pkl', 'rb') as f:
    history = pickle.load(f)
history
# Out:
# {'acc': [0.8083132530982235,
#   0.8067469879230821,
#   0.8104819275672177,
#   0.8125301204244775,
#   0.8100000000574502,
#   0.8162650602984142,
#   0.8149397588925189,
#   0.8274698795180723,
#   0.8227710843660745,
#   0.8306024096098291],
#  'loss': [0.7168388979406242,
#   0.7093381974496037,
#   0.6998840465890356,
#   0.6957869564050652,
#   0.676881012916565,
#   0.6768128811020448,
#   0.6483730292894754,
#   0.6338203935738069,
#   0.6405688757135207,
#   0.6113345612388059],
#  'val_acc': [0.9359016937894388,
#   0.9362338093656593,
#   0.9342411159083361,
#   0.9365659249418797,
#   0.9370640983062105,
#   0.9368980405181003,
#   0.935403520425108,
#   0.9355695781934226,
#   0.9350714048488874,
#   0.9344071736964463],
#  'val_loss': [0.21826742887769138,
#   0.22135266196477585,
#   0.22131480873361037,
#   0.21983840773032118,
#   0.21669106197128044,
#   0.21884617290627525,
#   0.21898912704988635,
#   0.22197841936292462,
#   0.21856036358452624,
# ...

# %%
EPOCHS = 10

# %%
plot_training_loss(history, EPOCHS)

# %%
plot_accuracy_loss(history, EPOCHS)

# %% [markdown]
# # 3rd Training
# **Baseline Model:** InceptionResNetV2
# <br>
# **Optimizer:** Adam, with learning rate 0.0001
# <br>
# **Image shape:** 299x299x3
# <br>
# **Validation Accuracy:** 0.9350
# <br>
# **Training Accuracy:** 0.7842

# %%
with open('dataset2/inception_adam.pkl', 'rb') as f:
    history = pickle.load(f)
history
# Out:
# {'acc': [0.5855421687034239,
#   0.7251807228915662,
#   0.7519277108433735,
#   0.7587951807803418,
#   0.7686746988813561,
#   0.7736144579462259,
#   0.7780722891279014,
#   0.784216867354979,
#   0.7873493975329112,
#   0.7855421688183244],
#  'loss': [1.931720118924796,
#   1.1350871134378824,
#   1.0097846865653992,
#   0.959931597307504,
#   0.9220541538962399,
#   0.878033452579774,
#   0.8631889052563403,
#   0.8176748893347131,
#   0.820286998131189,
#   0.8054091848379158],
#  'val_acc': [0.9267685154433742,
#   0.9232813018930588,
#   0.9305878445501147,
#   0.9282630355363667,
#   0.9279309199601461,
#   0.9342411159281317,
#   0.9289272666888077,
#   0.9352374626172021,
#   0.9294254400531385,
#   0.9312520757223514],
#  'val_loss': [0.2761239283101102,
#   0.2778183602511744,
#   0.25929531125442723,
#   0.2760939099722301,
#   0.27804072893233006,
#   0.26622491783475766,
#   0.2603110273930667,
#   0.2526534817728073,
#   0.27284156954722005,
# ...

# %%
EPOCHS = 10

# %%
plot_training_loss(history, EPOCHS)

# %%
plot_accuracy_loss(history, EPOCHS)

# %% [markdown]
# # 3rd Training
# **Baseline Model:** InceptionResNetV2
# <br>
# **Optimizer:** RMS, with learning rate 0.0001
# <br>
# **Image shape:** 299x299x3
# <br>
# **Validation Accuracy:** 0.9322
# <br>
# **Training Accuracy:** 0.7765

# %%
with open('dataset2/inception_rms.pkl', 'rb') as f:
    history = pickle.load(f)
history
# Out:
# {'acc': [0.5486746989100812,
#   0.7114457832187056,
#   0.7357831323864948,
#   0.7467469879518073,
#   0.7543373493688652,
#   0.7638554216005716,
#   0.7685542167238443,
#   0.7698795182159148,
#   0.776506023981485,
#   0.7797590362307537],
#  'loss': [2.4820958960774435,
#   1.3552329957916076,
#   1.229319579831089,
#   1.1382388845122005,
#   1.1159151196767048,
#   1.0452131463246173,
#   1.042842911955822,
#   1.0255043563498072,
#   1.030645054420793,
#   0.9745367982588619],
#  'val_acc': [0.9078379275988043,
#   0.9191298571705065,
#   0.9229491862970426,
#   0.9275988043839256,
#   0.9232813018930588,
#   0.9284290933046813,
#   0.9239455330454999,
#   0.9289272667086034,
#   0.9322484224312173,
#   0.9314181335104617],
#  'val_loss': [0.36774986747751887,
#   0.33095535042326696,
#   0.32572759248932426,
#   0.31743215253023827,
#   0.3474606911084831,
#   0.3243139833762465,
#   0.34109041821604397,
#   0.331298551821295,
#   0.3150538877395054,
# ...

# %%
EPOCHS = 10

# %%
plot_training_loss(history, EPOCHS)

# %%
plot_accuracy_loss(history, EPOCHS)
