# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot_training_loss(history, epochs):
    plt.style.use("ggplot")
    plt.plot(np.arange(0, epochs), history['loss'])
    plt.plot(np.arange(0, epochs), history['val_loss'])
    plt.title('Training Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train_loss', 'val_loss'], loc='upper left')
    plt.show()
    
def plot_training_accuracy(history, epochs):
    plt.style.use("ggplot")
    plt.plot(np.arange(0, epochs), history['acc'])
    plt.plot(np.arange(0, epochs), history['val_acc'])
    plt.title('Training Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train_acc', 'val_acc'], loc='upper left')

# %% [markdown]
# # 1st Training
# **Baseline Model:** ResNet50
# <br>
# **Optimizer:** RMSprop, with learning rate 0.0001
# <br>
# **Image shape:** 224x224x3
# <br>
# **Validation Accuracy:** 0.7095
# <br>
# **Training Accuracy:** 0.7730

# %%
with open('history_resnet_rmsprop.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
EPOCHS = 10

# %%
plot_training_loss(history, EPOCHS)

# %%
plot_training_accuracy(history, EPOCHS)

# %% [markdown]
# # 2nd Training
# **Baseline Model:** ResNet50
# <br>
# **Optimizer:** Adam, with learning rate 0.00005
# <br>
# **Image shape:** 208x208x3
# <br>
# **Validation Accuracy:** 0.8143
# <br>
# **Training Accuracy:** 0.8167

# %%
with open('history_resnet_adam.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
EPOCHS = 20

# %%
plot_training_loss(history, EPOCHS)

# %%
plot_training_accuracy(history, EPOCHS)

# %% [markdown]
# # 3rd Training
# **Baseline Model:** InceptionV3
# <br>
# **Optimizer:** Adam, with learning rate 0.00005
# <br>
# **Image shape:** 208x208x3
# <br>
# **Validation Accuracy:** 0.8143
# <br>
# **Training Accuracy:** 0.7952

# %%
with open('history_inceptionv3_adam.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
EPOCHS = 20

# %%
plot_training_loss(history, EPOCHS)

# %%
plot_training_accuracy(history, EPOCHS)

# %% [markdown]
# # 4th Training - Final
# **Baseline Model:** InceptionResNetV2
# <br>
# **Optimizer:** Adam, with learning rate 0.00005
# <br>
# **Image shape:** 199x199x3
# <br>
# **Validation Accuracy:** 0.8302
# <br>
# **Training Accuracy:** 0.8393

# %%
with open('history_inceptionresnetv2_adam.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
EPOCHS = 15

# %%
plot_training_loss(history, EPOCHS)

# %%
plot_training_accuracy(history, EPOCHS)
