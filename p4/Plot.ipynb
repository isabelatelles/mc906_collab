# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # First Training
# **Baseline Model:** ResNet50
# <br>
# **Optimizer:** RMSprop, with learning rate 0.0001
# <br>
# **Image shape:** 224x224x3
# <br>
# **Validation Accuracy:** 0.8143
# <br>
# **Training Accuracy:** 0.8167

# %%
with open('history.pkl', 'rb') as f:
    history = pickle.load(f)
history
# Out:
# {'acc': [0.11785714543823685,
#   0.36547619317259106,
#   0.558333335178239,
#   0.6515872980867113,
#   0.7095238072531563,
#   0.7718253995691027,
#   0.7880952375275748,
#   0.8186507957322257,
#   0.8547619053295681,
#   0.8678571445601327],
#  'loss': [3.478988174029759,
#   2.2917880262647357,
#   1.6241477506501334,
#   1.2394510567188264,
#   1.034493499142783,
#   0.8538197640861783,
#   0.753911050089768,
#   0.6445293256214687,
#   0.5309540557009833,
#   0.4885612055659294],
#  'val_acc': [0.5206349202564784,
#   0.6888888869966779,
#   0.7142857210976737,
#   0.7746031761169434,
#   0.7730158686637878,
#   0.7444444383893695,
#   0.7936508008411952,
#   0.7507936460631234,
#   0.7952380895614624,
#   0.766666659287044],
#  'val_loss': [1.864966058731079,
#   1.0973548889160156,
#   0.8537375722612653,
#   0.8442908389227731,
#   0.7906627944537572,
#   1.0411944789545877,
#   0.8234552502632141,
#   1.246978850024087,
#   0.9314822205475398,
#   1.2708599158695766]}

# %%
EPOCHS = 10

# %%
plt.style.use("ggplot")
plt.plot(np.arange(0, EPOCHS), history['loss'])
plt.plot(np.arange(0, EPOCHS), history['val_loss'])
plt.title('Training Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train_loss', 'val_loss'], loc='upper left')
plt.show()

# %%
plt.style.use("ggplot")
plt.plot(np.arange(0, EPOCHS), history['acc'])
plt.plot(np.arange(0, EPOCHS), history['val_acc'])
plt.title('Accuracy Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train_acc', 'val_acc'], loc='upper left')
plt.show()

# %% [markdown]
# # Second Training
# **Baseline Model:** ResNet50
# <br>
# **Optimizer:** Adam, with learning rate 0.00005
# <br>
# **Image shape:** 208x208x3
# <br>
# **Validation Accuracy:** 0.8143
# <br>
# **Training Accuracy:** 0.8167

# %%
with open('history_3.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
EPOCHS = 20

# %%
plt.style.use("ggplot")
plt.plot(np.arange(0, EPOCHS), history['loss'])
plt.plot(np.arange(0, EPOCHS), history['val_loss'])
plt.title('Training Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train_loss', 'val_loss'], loc='upper left')
plt.show()

# %%
plt.style.use("ggplot")
plt.plot(np.arange(0, EPOCHS), history['acc'])
plt.plot(np.arange(0, EPOCHS), history['val_acc'])
plt.title('Accuracy Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train_acc', 'val_acc'], loc='upper left')
plt.show()
